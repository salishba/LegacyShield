# %%
pip install transformers datasets torch accelerate optimum[onnxruntime] xgboost scikit-learn pandas onnxruntime
# Out:
# Requirement already satisfied: transformers in e:\download\anaconda\lib\site-packages (4.57.6)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: datasets in e:\download\anaconda\lib\site-packages (4.6.1)
# Requirement already satisfied: torch in e:\download\anaconda\lib\site-packages (2.10.0)
# Requirement already satisfied: accelerate in e:\download\anaconda\lib\site-packages (1.12.0)
# Requirement already satisfied: xgboost in e:\download\anaconda\lib\site-packages (3.2.0)
# Requirement already satisfied: scikit-learn in e:\download\anaconda\lib\site-packages (1.5.1)
# Requirement already satisfied: pandas in e:\download\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: onnxruntime in e:\download\anaconda\lib\site-packages (1.24.2)
# Requirement already satisfied: optimum[onnxruntime] in e:\download\anaconda\lib\site-packages (2.1.0)
# Requirement already satisfied: filelock in e:\download\anaconda\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in e:\download\anaconda\lib\site-packages (from transformers) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in e:\download\anaconda\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\download\anaconda\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in e:\download\anaconda\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in e:\download\anaconda\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in e:\download\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in e:\download\anaconda\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in e:\download\anaconda\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in e:\download\anaconda\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=21.0.0 in e:\download\anaconda\lib\site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in e:\download\anaconda\lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in e:\download\anaconda\lib\site-packages (from datasets) (0.27.0)
# Requirement already satisfied: xxhash in e:\download\anaconda\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in e:\download\anaconda\lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in e:\download\anaconda\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\download\anaconda\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\download\anaconda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in e:\download\anaconda\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in e:\download\anaconda\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in e:\download\anaconda\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: psutil in e:\download\anaconda\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: optimum-onnx[onnxruntime] in e:\download\anaconda\lib\site-packages (from optimum[onnxruntime]) (0.1.0)
# Requirement already satisfied: scipy in e:\download\anaconda\lib\site-packages (from xgboost) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in e:\download\anaconda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\download\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\download\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\download\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\download\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: flatbuffers in e:\download\anaconda\lib\site-packages (from onnxruntime) (25.12.19)
# Requirement already satisfied: protobuf in e:\download\anaconda\lib\site-packages (from onnxruntime) (4.25.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in e:\download\anaconda\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: anyio in e:\download\anaconda\lib\site-packages (from httpx<1.0.0->datasets) (4.2.0)
# Requirement already satisfied: certifi in e:\download\anaconda\lib\site-packages (from httpx<1.0.0->datasets) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in e:\download\anaconda\lib\site-packages (from httpx<1.0.0->datasets) (1.0.2)
# Requirement already satisfied: idna in e:\download\anaconda\lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: sniffio in e:\download\anaconda\lib\site-packages (from httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\download\anaconda\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: six>=1.5 in e:\download\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\download\anaconda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\download\anaconda\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\download\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in e:\download\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\download\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: onnx in e:\download\anaconda\lib\site-packages (from optimum-onnx[onnxruntime]; extra == "onnxruntime"->optimum[onnxruntime]) (1.20.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in e:\download\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\download\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in e:\download\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\download\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\download\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\download\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in e:\download\anaconda\lib\site-packages (from onnx->optimum-onnx[onnxruntime]; extra == "onnxruntime"->optimum[onnxruntime]) (0.5.4)

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.10.0+cpu
# False
